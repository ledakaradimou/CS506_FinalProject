# %%
from lxml import html
import requests
from collections import OrderedDict
import pprint
import json
import argparse

# %%
urls = []
with open('links.csv', 'r') as f:
    for i in (f):
        urls.append(('https://www.tripadvisor.com'+i).strip('\n'))
print(urls)
# Out:
# ['https://www.tripadvisor.com/Restaurant_Review-g293986-d7267482-Reviews-Brisket-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d3389330-Reviews-Pizza_Roma_Cafe-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d2084697-Reviews-Habibah_Sweets-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d1371269-Reviews-Fakhreldin_Restaurant-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d2406112-Reviews-Sufra_Restaurant-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d3989474-Reviews-V_Lounge_Restaurant-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d1641029-Reviews-Tawaheen_al_Hawa-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Restaurant_Review-g293986-d7761403-Reviews-Chestnut_Restaurant_Pub-Amman_Amman_Governorate.html', 'https://www.tripadvisor.com/Resta
# ...

# %%
for k in urls:
